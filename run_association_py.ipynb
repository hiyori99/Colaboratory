# %% [markdown]
# <a href="https://colab.research.google.com/github/hiyori99/Colaboratory/blob/main/run_association_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# !ls
# Out:
# association2.ipynb  greom.ipynb      Untitled1.ipynb
# association.ipynb   Untitled0.ipynb  Untitled2.ipynb

# %%
# !jupyter nbconvert --to python association.ipynb
# Out:
# [NbConvertApp] Converting notebook association.ipynb to python
# [NbConvertApp] Writing 2093 bytes to association.py

# %%
# !python association.py
# Out:
#        発注番号    商品番号                                 商品説明  商品個数  \
# 100  537065   21054                 NURSE'S BAG SOFT TOY     6
# 101  537065   21055                   TOOL BOX SOFT TOY      6
# 102  537065   21892   TRADITIONAL WOODEN CATCH CUP GAME     12
# 103  537065   22619            SET OF 6 SOLDIER SKITTLES     4
# 104  537065  84963A          PINK PAINTED KASHMIRI CHAIR     4
# 105  537065    POST                              POSTAGE     9
# 106  537463   22961               JAM MAKING SET PRINTED    12
# 107  537463   21224                   SET/4 SKULL BADGES    10
# 108  537463   22326  ROUND SNACK BOXES SET OF4 WOODLAND     18
# 109  537463   21124   SET/10 BLUE POLKADOT PARTY CANDLES    24
#
#                   明細書発行日    商品単価       顧客番号      国名  発注種別
# 100  2010-12-05 11:57:00  8.9500 12567.0000  France     5
# 101  2010-12-05 11:57:00  8.9500 12567.0000  France     5
# 102  2010-12-05 11:57:00  1.2500 12567.0000  France     5
# ...
